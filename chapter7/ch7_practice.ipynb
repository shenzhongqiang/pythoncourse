# %%
import tushare as ts
df = ts.get_stock_basics()

# %%
df.pe.median()
# Out:
# 26.02

# %%
df_company = df[df.pe>0][["name", "pe", "pb"]].sort_values("pe").head(10)

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = Bar()
bar.add_xaxis(df_company.name.values.tolist())
bar.add_yaxis("市盈率", df_company.pe.values.tolist())
bar.add_yaxis("市净率", df_company.pb.values.tolist())

bar.set_global_opts(title_opts=opts.TitleOpts(title="市盈率"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b8e07a2bf20f4c16ac46f001b9f435d0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b8e07a2bf20f4c16ac46f001b9f435d0 = echarts.init(
#                     document.getElementById('b8e07a2bf20f4c16ac46f001b9f435d0'), 'white', {renderer: 'canvas'});
#                 var option_b8e07a2bf20f4c16ac46f001b9f435d0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e02\u76c8\u7387",
#             "data": [
#                 2.31,
#                 2.56,
#                 3.28,
#                 3.88,
#                 3.89,
#                 4.08,
#                 4.28,
#                 4.31,
#                 4.4,
#                 4.53
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5e02\u51c0\u7387",
#             "data": [
#                 1.03,
#                 1.01,
#                 1.15,
#                 0.99,
#                 0.85,
#                 0.69,
#                 0.82,
#                 1.14,
#                 0.6,
#                 0.55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e02\u76c8\u7387",
#                 "\u5e02\u51c0\u7387"
#             ],
#             "selected": {
#                 "\u5e02\u76c8\u7387": true,
#                 "\u5e02\u51c0\u7387": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6d59\u6c5f\u5e7f\u53a6",
#                 "\u795e\u706b\u80a1\u4efd",
#                 "\u65b0\u96c6\u80fd\u6e90",
#                 "\u5e7f\u5b87\u53d1\u5c55",
#                 "\u534e\u83f1\u94a2\u94c1",
#                 "\u65b0\u94a2\u80a1\u4efd",
#                 "\u5357\u94a2\u80a1\u4efd",
#                 "\u4e94\u6d32\u4ea4\u901a",
#                 "\u6c11\u751f\u94f6\u884c",
#                 "ST\u8f85\u4ec1"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5e02\u76c8\u7387"
#         }
#     ]
# };
#                 chart_b8e07a2bf20f4c16ac46f001b9f435d0.setOption(option_b8e07a2bf20f4c16ac46f001b9f435d0);
#         });
#     </script>

# %%
df_num = df.groupby("area")["name"].agg({"company_num": "count"})
# Out:
# C:\Users\linushen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.
#       company_num
# area
# 上海            302
# 云南             36
# 内蒙             25
# 北京            343
# 吉林             42
# 四川            124
# 天津             54
# 宁夏             14
# 安徽            105
# 山东            209
# 山西             37
# 广东            318
# 广西             38
# 新疆             55
# 江苏            421
# 江西             42
# 河北             57
# 河南             78
# 浙江            456
# 海南             31
# 深圳            297
# 湖北            104
# 湖南            105
# 甘肃             33
# 福建            138
# 西藏             19
# 贵州             29
# 辽宁             72
# 重庆             52
# 陕西             53
# 青海             12
# 黑龙江            38

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Map
m = Map()

m.add("公司数量", [list(z) for z in zip(df_num.index.values.tolist(), df_num.company_num.values.tolist())], "china")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(max_=500, is_piecewise=True),
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="fd4cfdfc2ac646e1987104ab3fbfc698" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_fd4cfdfc2ac646e1987104ab3fbfc698 = echarts.init(
#                     document.getElementById('fd4cfdfc2ac646e1987104ab3fbfc698'), 'white', {renderer: 'canvas'});
#                 var option_fd4cfdfc2ac646e1987104ab3fbfc698 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 302
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5185\u8499",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 343
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 209
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 318
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 421
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 456
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 297
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 138
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 38
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u53f8\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u516c\u53f8\u6570\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 500,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#                 chart_fd4cfdfc2ac646e1987104ab3fbfc698.setOption(option_fd4cfdfc2ac646e1987104ab3fbfc698);
#         });
#     </script>

# %%
npr = df["npr"].median()/100
gpr = df["grp"].median()/100

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType

l = Liquid()
l.add("lq", [npr, gpr])
l.set_global_opts(title_opts=opts.TitleOpts(title="利润率"))
l.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="ef05cf4843f946a599d3e9eaafc66d41" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_ef05cf4843f946a599d3e9eaafc66d41 = echarts.init(
#                     document.getElementById('ef05cf4843f946a599d3e9eaafc66d41'), 'white', {renderer: 'canvas'});
#                 var option_ef05cf4843f946a599d3e9eaafc66d41 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.0728,
#                 0.27065
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5229\u6da6\u7387"
#         }
#     ]
# };
#                 chart_ef05cf4843f946a599d3e9eaafc66d41.setOption(option_ef05cf4843f946a599d3e9eaafc66d41);
#         });
#     </script>

# %%
df_industry = df.groupby("industry")["name"].agg({"company_num": "count"})
# Out:
# C:\Users\linushen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.
#           company_num
# industry
# IT设备               37
# 专用机械              137
# 中成药                69
# 乳制品                12
# 互联网                71
# ...               ...
# 银行                 36
# 陶瓷                  6
# 食品                 62
# 饲料                 17
# 黄金                 13
#
# [110 rows x 1 columns]

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType

words = [list(z) for z in zip(df_industry.index.values.tolist(), df_industry.company_num.values.tolist())]
wc = WordCloud()
wc.add("", words, word_size_range=[20, 100], shape="diamond")
wc.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="f68c70e9adc94bd0a2631e3fe48ac932" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_f68c70e9adc94bd0a2631e3fe48ac932 = echarts.init(
#                     document.getElementById('f68c70e9adc94bd0a2631e3fe48ac932'), 'white', {renderer: 'canvas'});
#                 var option_f68c70e9adc94bd0a2631e3fe48ac932 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "IT\u8bbe\u5907",
#                     "value": 37,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,151,108)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e13\u7528\u673a\u68b0",
#                     "value": 137,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,50,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u6210\u836f",
#                     "value": 69,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,92,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e73\u5236\u54c1",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,11,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 71,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,21,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ed3\u50a8\u7269\u6d41",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,103,66)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u6c14\u4f9b\u70ed",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,87,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fdd\u9669",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,128,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5143\u5668\u4ef6",
#                     "value": 180,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,47,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5168\u56fd\u5730\u4ea7",
#                     "value": 37,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,7,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5171\u4ea4\u901a",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,43,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u8def",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,138,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u5546\u4e1a",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,115,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u5efa\u6750",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,44,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u4e1a\u7efc\u5408",
#                     "value": 26,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,79,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u7528\u673a\u68b0",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,75,98)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u836f\u5316\u80a5",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,8,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u51fa\u7248\u4e1a",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,158,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5b66\u5236\u836f",
#                     "value": 103,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,53,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5de5\u539f\u6599",
#                     "value": 161,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,71,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5de5\u673a\u68b0",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,142,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u7ea4",

# %%
years = [i for i in range(2018, 2019, 1)]
quarters = [1,2,3,4]

dates = []
profits = []
incomes = []
for year in years:
    for quarter in quarters:
        df = ts.get_profit_data(year, quarter)
        print(year, quarter)
        df = df[df.code=="000001"]
        if len(df) == 0:
            raise Exception("error")
        s = df.iloc[0]
        net_profit = s["net_profits"]
        business_income = s["business_income"]
        date = "{}-{}".format(year, quarter * 3)
        dates.append(date)
        profits.append(net_profit)
        incomes.append(business_income)
print(profits)
print(incomes)
print(dates)
# Out:
# 2018 1
# [Getting data:]##############################################################2018 2
# [Getting data:]##############################################################2018 3
# [Getting data:]###############################################################2018 4
# [Getting data:]###############################################################[6595.0, 13372.0, 20456.0, 24818.0]
# [28026.0, 57241.0, 86664.0, 116716.0]
# ['2018-3', '2018-6', '2018-9', '2018-12']

# %%
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line

line = Line()
line.add_xaxis(dates)
line.add_yaxis("净利润", profits)
line.add_yaxis("营收", incomes)
line.set_global_opts(title_opts=opts.TitleOpts(title="盈利能力"))
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4824b5c6e82d4641867ca1b2bc522d6f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4824b5c6e82d4641867ca1b2bc522d6f = echarts.init(
#                     document.getElementById('4824b5c6e82d4641867ca1b2bc522d6f'), 'white', {renderer: 'canvas'});
#                 var option_4824b5c6e82d4641867ca1b2bc522d6f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u51c0\u5229\u6da6",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2018-3",
#                     6595.0
#                 ],
#                 [
#                     "2018-6",
#                     13372.0
#                 ],
#                 [
#                     "2018-9",
#                     20456.0
#                 ],
#                 [
#                     "2018-12",
#                     24818.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u8425\u6536",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2018-3",
#                     28026.0
#                 ],
#                 [
#                     "2018-6",
#                     57241.0
#                 ],
#                 [
#                     "2018-9",
#                     86664.0
#                 ],
#                 [
#                     "2018-12",
#                     116716.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u51c0\u5229\u6da6",
#                 "\u8425\u6536"
#             ],
#             "selected": {
#                 "\u51c0\u5229\u6da6": true,
#                 "\u8425\u6536": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2018-3",
#                 "2018-6",
#                 "2018-9",
#                 "2018-12"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u76c8\u5229\u80fd\u529b"
#         }
#     ]
# };
#                 chart_4824b5c6e82d4641867ca1b2bc522d6f.setOption(option_4824b5c6e82d4641867ca1b2bc522d6f);
#         });
#     </script>
