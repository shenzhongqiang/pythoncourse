# %%
from datetime import datetime 
from pandas import Series
import numpy as np

dates=[datetime(2019,11,1),datetime(2019,11,2),datetime(2019,11,3),datetime(2019,11,4),datetime(2019,11,5),datetime(2019,11,6)]
ts=Series(np.random.randn(6),index=dates)
ts
# Out:
# 2019-11-01    0.916997
# 2019-11-02   -0.305304
# 2019-11-03   -2.422390
# 2019-11-04    0.312260
# 2019-11-05   -0.235379
# 2019-11-06    0.554946
# dtype: float64

# %%
ts + ts[::2]
# Out:
# 2019-11-01    1.833994
# 2019-11-02         NaN
# 2019-11-03   -4.844780
# 2019-11-04         NaN
# 2019-11-05   -0.470757
# 2019-11-06         NaN
# dtype: float64

# %%
#ts['2019-11-01']
#ts['20191101']
ts['11/1/2019']
# Out:
# 0.916996874096383

# %%
longer_ts = pd.Series(np.random.randn(1000).cumsum(),index=pd.date_range('1/1/2000',periods=1000))
longer_ts
longer_ts['2001']
# Out:
# 2001-01-01    -5.402299
# 2001-01-02    -6.152364
# 2001-01-03    -6.077441
# 2001-01-04    -5.860238
# 2001-01-05    -4.769915
#                 ...
# 2001-12-27   -12.777882
# 2001-12-28   -13.356302
# 2001-12-29   -12.343049
# 2001-12-30   -11.787793
# 2001-12-31   -10.886452
# Freq: D, Length: 365, dtype: float64

# %%
longer_ts['2001-01']
# Out:
# 2001-01-01    -5.402299
# 2001-01-02    -6.152364
# 2001-01-03    -6.077441
# 2001-01-04    -5.860238
# 2001-01-05    -4.769915
# 2001-01-06    -4.899945
# 2001-01-07    -4.655535
# 2001-01-08    -5.842838
# 2001-01-09    -5.908763
# 2001-01-10    -5.958213
# 2001-01-11    -5.159726
# 2001-01-12    -5.598065
# 2001-01-13    -6.215181
# 2001-01-14    -6.978026
# 2001-01-15    -7.185535
# 2001-01-16    -5.281061
# 2001-01-17    -5.251486
# 2001-01-18    -5.186686
# 2001-01-19    -4.233068
# 2001-01-20    -6.054920
# 2001-01-21    -4.996328
# 2001-01-22    -4.948222
# 2001-01-23    -4.774343
# 2001-01-24    -5.993764
# 2001-01-25    -7.719411
# 2001-01-26    -7.782463
# 2001-01-27    -8.394503
# 2001-01-28   -10.377900
# 2001-01-29    -8.894973
# 2001-01-30    -8.301638
# 2001-01-31    -9.167145
# Freq: D, dtype: float64

# %%
longer_ts[datetime(2001,1,1):]
# Out:
# 2001-01-01    -5.402299
# 2001-01-02    -6.152364
# 2001-01-03    -6.077441
# 2001-01-04    -5.860238
# 2001-01-05    -4.769915
#                 ...
# 2002-09-22   -18.157618
# 2002-09-23   -16.970807
# 2002-09-24   -16.054685
# 2002-09-25   -18.409106
# 2002-09-26   -20.161925
# Freq: D, Length: 634, dtype: float64

# %%
longer_ts['1/1/2001':'1/6/2001']
# Out:
# 2001-01-01   -5.402299
# 2001-01-02   -6.152364
# 2001-01-03   -6.077441
# 2001-01-04   -5.860238
# 2001-01-05   -4.769915
# 2001-01-06   -4.899945
# Freq: D, dtype: float64

# %%
dates = pd.date_range('1/1/2000',periods=100,freq='D')
long_df = pd.DataFrame(np.random.randn(100,4).cumsum(axis=0),index=dates,columns=['EBAY','MSFT','AAPL','AMZN'])
long_df
# Out:
#                 EBAY      MSFT      AAPL      AMZN
# 2000-01-01  1.513472  0.273861  0.413006  0.824267
# 2000-01-02  2.153450  1.412259  0.262805 -0.840383
# 2000-01-03  2.725904 -0.575383 -0.224316  0.165827
# 2000-01-04  3.879591 -0.754127 -0.863387  0.754900
# 2000-01-05  5.354508 -1.757742  0.271970 -0.500199
# ...              ...       ...       ...       ...
# 2000-04-05 -6.559590  5.328542 -8.131943  1.971528
# 2000-04-06 -6.663055  7.053308 -7.624965  3.124927
# 2000-04-07 -6.389433  5.583975 -6.056610  2.460591
# 2000-04-08 -6.672380  5.465516 -8.660621  1.854518
# 2000-04-09 -6.114686  4.205847 -7.355110  0.215223
#
# [100 rows x 4 columns]

# %%
long_df.loc['2000-2']
# Out:
#                 EBAY      MSFT      AAPL      AMZN
# 2000-02-01  3.520743  1.600362 -3.918388  1.022138
# 2000-02-02  3.115440  1.618127 -4.179149  0.319660
# 2000-02-03  2.433851  1.157442 -4.782893  0.441067
# 2000-02-04  2.933672  0.952261 -5.652691  0.607670
# 2000-02-05  0.825256  0.957139 -5.498649  1.597075
# 2000-02-06  1.898123 -0.094769 -5.106513  1.872896
# 2000-02-07  2.220822 -0.386782 -4.688542  1.122333
# 2000-02-08  1.116698 -2.186867 -4.425758  2.923370
# 2000-02-09  1.834094 -3.087456 -5.236873  1.353792
# 2000-02-10  3.031629 -3.181025 -5.860758  0.645046
# 2000-02-11  2.385104 -3.199958 -5.254773 -0.398391
# 2000-02-12  1.048437 -2.092825 -2.877609  0.795735
# 2000-02-13 -0.099085 -2.566320 -2.374000  1.864224
# 2000-02-14 -1.627223 -2.294769 -3.665459 -0.403834
# 2000-02-15 -2.490505 -3.674034 -3.173241 -0.159119
# 2000-02-16 -3.033270 -4.559887 -4.277815 -0.560064
# 2000-02-17 -1.617283 -4.720374 -3.755691 -1.285003
# 2000-02-18 -1.800730 -4.634297 -3.403244 -2.628470
# 2000-02-19 -2.834311 -5.569428 -2.898053 -2.409993
# 2000-02-20 -3.184979 -5.634865 -3.460512 -2.891728
# 2000-02-21 -3.746569 -6.137078 -1.900585 -2.408669
# 2000-02-22 -4.180163 -8.019345 -1.530635 -2.045986
# 2000-02-23 -4.398048 -8.790576 -1.376929 -0.686499
# 2000-02-24 -5.453882 -8.010880 -1.073837 -1.579211
# 2000-02-25 -7.110415 -9.167881 -0.208654 -1.223542
# 2000-02-26 -5.979887 -8.962887  0.150321 -1.993861
# 2000-02-27 -6.688568 -7.919271 -0.021127 -1.496263
# 2000-02-28 -8.776049 -7.379266 -0.866873 -2.278668
# 2000-02-29 -8.186979 -5.918089 -2.505661 -1.499397

# %%
index=pd.date_range('4/1/2019','6/1/2019')
index
# Out:
# DatetimeIndex(['2019-04-01', '2019-04-02', '2019-04-03', '2019-04-04',
#                '2019-04-05', '2019-04-06', '2019-04-07', '2019-04-08',
#                '2019-04-09', '2019-04-10', '2019-04-11', '2019-04-12',
#                '2019-04-13', '2019-04-14', '2019-04-15', '2019-04-16',
#                '2019-04-17', '2019-04-18', '2019-04-19', '2019-04-20',
#                '2019-04-21', '2019-04-22', '2019-04-23', '2019-04-24',
#                '2019-04-25', '2019-04-26', '2019-04-27', '2019-04-28',
#                '2019-04-29', '2019-04-30', '2019-05-01', '2019-05-02',
#                '2019-05-03', '2019-05-04', '2019-05-05', '2019-05-06',
#                '2019-05-07', '2019-05-08', '2019-05-09', '2019-05-10',
#                '2019-05-11', '2019-05-12', '2019-05-13', '2019-05-14',
#                '2019-05-15', '2019-05-16', '2019-05-17', '2019-05-18',
#                '2019-05-19', '2019-05-20', '2019-05-21', '2019-05-22',
#                '2019-05-23', '2019-05-24', '2019-05-25', '2019-05-26',
#                '2019-05-27', '2019-05-28', '2019-05-29', '2019-05-30',
#                '2019-05-31', '2019-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='4/1/2019',periods=20)
# Out:
# DatetimeIndex(['2019-04-01', '2019-04-02', '2019-04-03', '2019-04-04',
#                '2019-04-05', '2019-04-06', '2019-04-07', '2019-04-08',
#                '2019-04-09', '2019-04-10', '2019-04-11', '2019-04-12',
#                '2019-04-13', '2019-04-14', '2019-04-15', '2019-04-16',
#                '2019-04-17', '2019-04-18', '2019-04-19', '2019-04-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end='6/1/2019',periods=20)
# Out:
# DatetimeIndex(['2019-05-13', '2019-05-14', '2019-05-15', '2019-05-16',
#                '2019-05-17', '2019-05-18', '2019-05-19', '2019-05-20',
#                '2019-05-21', '2019-05-22', '2019-05-23', '2019-05-24',
#                '2019-05-25', '2019-05-26', '2019-05-27', '2019-05-28',
#                '2019-05-29', '2019-05-30', '2019-05-31', '2019-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('1/1/2019','12/1/2019',freq='BM')
# Out:
# DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-29', '2019-04-30',
#                '2019-05-31', '2019-06-28', '2019-07-31', '2019-08-30',
#                '2019-09-30', '2019-10-31', '2019-11-29'],
#               dtype='datetime64[ns]', freq='BM')

# %%
from pandas.tseries.offsets import Hour,Minute
four_hours = Hour(4)
pd.date_range('1/1/2019','1/3/2019 23:59',freq='4h')
# Out:
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 04:00:00',
#                '2019-01-01 08:00:00', '2019-01-01 12:00:00',
#                '2019-01-01 16:00:00', '2019-01-01 20:00:00',
#                '2019-01-02 00:00:00', '2019-01-02 04:00:00',
#                '2019-01-02 08:00:00', '2019-01-02 12:00:00',
#                '2019-01-02 16:00:00', '2019-01-02 20:00:00',
#                '2019-01-03 00:00:00', '2019-01-03 04:00:00',
#                '2019-01-03 08:00:00', '2019-01-03 12:00:00',
#                '2019-01-03 16:00:00', '2019-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
pd.date_range('1/1/2019','1/3/2019 23:59',freq=four_hours)
# Out:
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 04:00:00',
#                '2019-01-01 08:00:00', '2019-01-01 12:00:00',
#                '2019-01-01 16:00:00', '2019-01-01 20:00:00',
#                '2019-01-02 00:00:00', '2019-01-02 04:00:00',
#                '2019-01-02 08:00:00', '2019-01-02 12:00:00',
#                '2019-01-02 16:00:00', '2019-01-02 20:00:00',
#                '2019-01-03 00:00:00', '2019-01-03 04:00:00',
#                '2019-01-03 08:00:00', '2019-01-03 12:00:00',
#                '2019-01-03 16:00:00', '2019-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
longer_ts
# Out:
# 2000-01-01    -0.083893
# 2000-01-02    -1.925386
# 2000-01-03    -2.609284
# 2000-01-04    -3.365790
# 2000-01-05    -4.006248
#                 ...
# 2002-09-22   -18.157618
# 2002-09-23   -16.970807
# 2002-09-24   -16.054685
# 2002-09-25   -18.409106
# 2002-09-26   -20.161925
# Freq: D, Length: 1000, dtype: float64

# %%
longer_ts.resample('W').asfreq()
# Out:
# 2000-01-02    -1.925386
# 2000-01-09    -6.846395
# 2000-01-16    -6.639525
# 2000-01-23    -8.150777
# 2000-01-30    -1.281073
#                 ...
# 2002-09-01   -19.950365
# 2002-09-08   -18.705651
# 2002-09-15   -17.713782
# 2002-09-22   -18.157618
# 2002-09-29          NaN
# Freq: W-SUN, Length: 144, dtype: float64

# %%
longer_ts.resample('W').mean()
# Out:
# 2000-01-02    -1.004639
# 2000-01-09    -4.722297
# 2000-01-16    -8.458616
# 2000-01-23    -6.628849
# 2000-01-30    -3.861540
#                 ...
# 2002-09-01   -21.244437
# 2002-09-08   -18.896306
# 2002-09-15   -19.287861
# 2002-09-22   -17.863307
# 2002-09-29   -17.899131
# Freq: W-SUN, Length: 144, dtype: float64

# %%
np.random.seed(1)
ts=Series(np.random.randn(4),index=pd.date_range('1/1/2019',periods=4,freq='M'))
ts
# Out:
# 2019-01-31    1.624345
# 2019-02-28   -0.611756
# 2019-03-31   -0.528172
# 2019-04-30   -1.072969
# Freq: M, dtype: float64

# %%
ts.shift(2)
# Out:
# 2019-01-31         NaN
# 2019-02-28         NaN
# 2019-03-31    1.624345
# 2019-04-30   -0.611756
# Freq: M, dtype: float64

# %%
ts.shift(-2)
# Out:
# 2019-01-31   -0.528172
# 2019-02-28   -1.072969
# 2019-03-31         NaN
# 2019-04-30         NaN
# Freq: M, dtype: float64

# %%
ts.shift(2,freq='M')
# Out:
# 2019-03-31    1.624345
# 2019-04-30   -0.611756
# 2019-05-31   -0.528172
# 2019-06-30   -1.072969
# Freq: M, dtype: float64

# %%
ts.shift(3,freq='D')
# Out:
# 2019-02-03    1.624345
# 2019-03-03   -0.611756
# 2019-04-03   -0.528172
# 2019-05-03   -1.072969
# dtype: float64

# %%
dates = pd.date_range(start='2019-11-01', periods=5)
df = pd.DataFrame(data={'close': [10, 10.5, 11, 10.7, 10.8]}, index=dates)
df
# Out:
#             close
# 2019-11-01   10.0
# 2019-11-02   10.5
# 2019-11-03   11.0
# 2019-11-04   10.7
# 2019-11-05   10.8

# %%
df.close.shift(1)
# Out:
# 2019-11-01     NaN
# 2019-11-02    10.0
# 2019-11-03    10.5
# 2019-11-04    11.0
# 2019-11-05    10.7
# Freq: D, Name: close, dtype: float64

# %%
df.close/df.close.shift(1) - 1
# Out:
# 2019-11-01         NaN
# 2019-11-02    0.050000
# 2019-11-03    0.047619
# 2019-11-04   -0.027273
# 2019-11-05    0.009346
# Freq: D, Name: close, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(100, 3).cumsum(0),
    columns=['A', 'B', 'C'],
    index=pd.date_range('2019-01-01', periods=100))
df['A'].plot()

# %%
import tushare as ts
df = ts.get_stock_basics()
df
# Out:
#         name industry area      pe  outstanding  totals  totalAssets  \
# code
# 688111   N金山     软件服务   北京  213.71         0.67    4.61        19.66
# 300803  N指南针     软件服务   北京   21.78         0.57    4.05        12.23
# 002502  鼎龙文化     影视音像   广东    0.00         6.97    8.60        17.65
# 000859  国风塑业       塑料   安徽   32.84         7.39    7.39        21.01
# 600677  航天通信     通信设备   浙江    0.00         4.54    5.22       137.60
# ...      ...      ...  ...     ...          ...     ...          ...
# 300808  久量股份     电气设备   广东    0.00         0.00    0.00         9.81
# 300806   斯迪克       塑料   江苏    0.00         0.00    0.00        18.67
# 300805  电声股份     广告包装   广东    0.00         0.00    0.00        17.23
# 300801  泰和科技     化工原料   山东    0.00         0.00    0.00         9.13
# 300798  锦鸡股份     染料涂料   江苏    0.00         0.00    0.00        12.85
#
#         liquidAssets  fixedAssets  reserved  ...   bvps    pb  timeToMarket  \
# code                                         ...
# 688111         18.25         0.49      2.26  ...  12.73  9.92      20191118
# 300803          8.63         3.43      0.12  ...   2.70  3.33      20191118
# 002502         12.36         0.69     16.37  ...   1.94  1.79      20101117
# 000859          8.69         7.70      5.90  ...   2.21  1.98      19981119
# 600677        100.36        16.36     21.24  ...   5.99  1.21      19930928
# ...              ...          ...       ...  ...    ...   ...           ...
# 300808          5.27         2.48      1.98  ...   0.00  0.00             0
# 300806          9.15         6.85      2.72  ...   0.00  0.00             0
# 300805         16.14         0.22      1.71  ...   0.00  0.00             0
# 300801          3.89         2.64      2.59  ...   0.00  0.00             0
# 300798          7.85         2.84      1.02  ...   0.00  0.00             0
#
#         undp  perundp     rev   profit    gpr    npr   holders
# code
# 688111  7.83     1.70    0.00     0.00  83.96  19.62   46069.0
# 300803  3.87     0.96    0.00     0.00  87.35  23.66  109509.0
# 002502 -8.55    -0.99  512.63 -1494.35   6.84 -58.86   38986.0
# 000859  2.28     0.31   14.62    -1.11  12.34   7.36   72854.0
# 600677  4.56     0.87  -63.88  -303.55  15.37  -7.80   96926.0
# ...      ...      ...     ...      ...    ...    ...       ...
# 300808  2.76     0.00    0.00     0.00  23.92  10.33       0.0
# 300806  3.70     0.00    0.00     0.00  24.86   6.55       0.0
# 300805  5.28     0.00    0.00     0.00  21.00   7.24       0.0
# 300801  4.17     0.00    0.00     0.00  31.98  15.35       0.0
# 300798  5.02     0.00    0.00     0.00  21.24   8.75       0.0
#
# [3743 rows x 22 columns]

# %%
import tushare as ts
df = ts.get_report_data(2019, 3)
# Out:
# [Getting data:]###############################################################

# %%
df
# Out:
#         code  name   eps  eps_yoy  bvps    roe  epcf  net_profits  \
# 0     300803   指南针  0.36    24.14  2.28  17.14  0.19     12553.40
# 1     688111  金山办公  0.57    -1.72  3.92  15.71  0.69     20441.13
# 2     688101   三达膜  0.91    62.50  6.57  14.90  0.81     22879.14
# 3     688300  联瑞新材  0.83    20.29  5.54  15.90  0.92      5341.31
# 4     300796   贝斯美  0.57     5.56  6.53   8.69  0.37      5154.94
# ...      ...   ...   ...      ...   ...    ...   ...          ...
# 3721  000400  许继电气  0.26    71.45   NaN   3.23   NaN     26642.96
# 3722  002261  拓维信息  0.06    14.00   NaN   2.50   NaN      6292.09
# 3723  002714  牧原股份  0.66   288.24   NaN  10.29   NaN    138691.27
# 3724  002136   安纳达  0.18   -40.88   NaN   5.64   NaN      3946.51
# 3725  002913   奥士康  1.43    11.72   NaN   8.99   NaN     20621.23
#
#       profits_yoy distrib report_date
# 0           24.68     NaN       11-15
# 1           -2.51     NaN       11-15
# 2           64.38     NaN       11-14
# 3           25.61     NaN       11-14
# 4            4.22     NaN       11-14
# ...           ...     ...         ...
# 3721        71.45     NaN       10-12
# 3722        25.50     NaN       10-12
# 3723       296.04     NaN       10-12
# 3724       -40.87     NaN       10-10
# 3725        11.41     NaN       10-10
#
# [3726 rows x 11 columns]

# %%
ts.get_profit_data(2019,3)
# Out:
# [Getting data:]###############################################################
#         code   name    roe  net_profit_ratio  gross_profit_rate  net_profits  \
# 0     600083   博信股份  70.59              8.76             7.1966      14.3832
# 1     002234   民和股份  52.63             53.80            58.3539    1252.3255
# 2     002458   益生股份  51.03             61.55            64.5002    1468.5404
# 3     600768   宁波富邦  49.36             26.15             2.9585     113.1918
# 4     000526   紫光学大  44.25              2.62            28.9958      63.9875
# ...      ...    ...    ...               ...                ...          ...
# 3721  000911  *ST南糖    NaN            -21.19             1.4306    -538.7103
# 3722  000410  *ST沈机    NaN           -270.77           -47.6567   -2555.1622
# 3723  300090   盛运环保    NaN           -128.06            21.2391    -552.4927
# 3724  002356  *ST赫美    NaN            -62.49            48.7733    -416.5352
# 3725  600898   国美通讯    NaN            -30.40             1.4739    -208.0774
#
#          eps  business_income     bips
# 0     0.0625         164.0371   0.7132
# 1     4.1461        2327.6988   7.7064
# 2     2.5493        2385.9298   4.1419
# 3     0.8463         432.7077   3.2352
# 4     0.6651        2433.3378  25.2958
# ...      ...              ...      ...
# 3721 -1.6622        2541.1553   7.8411
# 3722 -3.3380         943.6491   1.2327
# 3723 -0.4185         431.4078   0.3268
# 3724 -0.7891         666.5128   1.2627
# 3725 -0.8239         684.4418   2.7104
#
# [3726 rows x 9 columns]

# %%
ts.get_operation_data(2014,3)
# Out:
# [Getting data:]################################################
#         code  name  arturnover  arturndays  inventory_turnover  \
# 0     600605  汇通能源      5.7747     46.7557         102298.4414
# 1     002649  博彦科技      3.0000     90.0000          37127.2743
# 2     002707  众信旅游     20.0313     13.4789           7704.9730
# 3     002039  黔源电力      7.8636     34.3354           6360.2514
# 4     300071  华谊嘉信      1.8090    149.2537           3002.9073
# ...      ...   ...         ...         ...                 ...
# 2817  000686  东北证券         NaN         NaN                 NaN
# 2818  300377   赢时胜      1.0842    249.0315                 NaN
# 2819  300033   同花顺     30.5068      8.8505                 NaN
# 2820  300491  通合科技         NaN         NaN                 NaN
# 2821  300499  高澜股份         NaN         NaN                 NaN
#
#       inventory_days  currentasset_turnover  currentasset_days
# 0             0.0026                 3.9518            68.3233
# 1             0.0073                 1.0532           256.3616
# 2             0.0350                 3.7006            72.9611
# 3             0.0425                 2.0979           128.7001
# 4             0.0899                 1.4096           191.5437
# ...              ...                    ...                ...
# 2817             NaN                    NaN                NaN
# 2818             NaN                 0.4882           553.0520
# 2819             NaN                 0.1467          1840.4908
# 2820             NaN                    NaN                NaN
# 2821             NaN                    NaN                NaN
#
# [2822 rows x 8 columns]

# %%
df = ts.get_hist_data('sz000001')

# %%
df
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2019-11-18  16.35  16.55  16.41  16.23   540238.94          0.07      0.43
# 2019-11-15  16.39  16.55  16.34  16.24   569228.00          0.02      0.12
# 2019-11-14  16.43  16.48  16.32  16.25   468899.56         -0.01     -0.06
# 2019-11-13  16.29  16.46  16.33  16.06   655120.62          0.00      0.00
# 2019-11-12  16.29  16.37  16.33  16.16   516266.41          0.05      0.31
# ...           ...    ...    ...    ...         ...           ...       ...
# 2017-05-26   9.08   9.13   9.10   9.04   895365.75          0.00      0.00
# 2017-05-25   8.79   9.14   9.10   8.78  1621543.62          0.29      3.29
# 2017-05-24   8.78   8.83   8.81   8.68   532376.69          0.02      0.23
# 2017-05-23   8.67   8.84   8.79   8.64   800040.19          0.11      1.27
# 2017-05-22   8.68   8.73   8.68   8.61   679120.06         -0.01     -0.12
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20
# date
# 2019-11-18  16.346  16.566  16.616  549950.71  730011.65  883609.75
# 2019-11-15  16.320  16.617  16.640  632606.04  764970.19  903895.42
# 2019-11-14  16.382  16.669  16.649  688588.28  833512.94  935273.97
# 2019-11-13  16.496  16.663  16.668  737187.76  872879.90  968138.11
# 2019-11-12  16.622  16.673  16.691  778828.71  892799.56  998765.64
# ...            ...     ...     ...        ...        ...        ...
# 2017-05-26   8.896   8.896   8.896  905689.26  905689.26  905689.26
# 2017-05-25   8.845   8.845   8.845  908270.14  908270.14  908270.14
# 2017-05-24   8.760   8.760   8.760  670512.31  670512.31  670512.31
# 2017-05-23   8.735   8.735   8.735  739580.13  739580.13  739580.13
# 2017-05-22   8.680   8.680   8.680  679120.06  679120.06  679120.06
#
# [610 rows x 13 columns]

# %%
df = ts.get_hist_data('sz000001', start="2019-01-01")

# %%
df
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2019-11-18  16.35  16.55  16.41  16.23   540238.94          0.07      0.43
# 2019-11-15  16.39  16.55  16.34  16.24   569228.00          0.02      0.12
# 2019-11-14  16.43  16.48  16.32  16.25   468899.56         -0.01     -0.06
# 2019-11-13  16.29  16.46  16.33  16.06   655120.62          0.00      0.00
# 2019-11-12  16.29  16.37  16.33  16.16   516266.41          0.05      0.31
# ...           ...    ...    ...    ...         ...           ...       ...
# 2019-01-08   9.73   9.74   9.66   9.62   402388.12         -0.08     -0.82
# 2019-01-07   9.84   9.85   9.74   9.63   865687.69         -0.01     -0.10
# 2019-01-04   9.24   9.82   9.75   9.22  1481159.00          0.47      5.07
# 2019-01-03   9.18   9.33   9.28   9.15   415537.97          0.09      0.98
# 2019-01-02   9.39   9.42   9.19   9.16   539386.31         -0.19     -2.03
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20
# date
# 2019-11-18  16.346  16.566  16.616  549950.71  730011.65  883609.75
# 2019-11-15  16.320  16.617  16.640  632606.04  764970.19  903895.42
# 2019-11-14  16.382  16.669  16.649  688588.28  833512.94  935273.97
# 2019-11-13  16.496  16.663  16.668  737187.76  872879.90  968138.11
# 2019-11-12  16.622  16.673  16.691  778828.71  892799.56  998765.64
# ...            ...     ...     ...        ...        ...        ...
# 2019-01-08   9.524   9.434   9.753  740831.82  642223.01  629898.29
# 2019-01-07   9.468   9.413   9.784  775674.99  702045.88  626789.69
# 2019-01-04   9.376   9.410   9.809  727456.11  714505.59  612448.63
# 2019-01-03   9.286   9.429   9.844  515452.42  626190.39  567467.94
# 2019-01-02   9.298   9.513   9.910  549667.92  638411.02  573431.70
#
# [213 rows x 13 columns]
